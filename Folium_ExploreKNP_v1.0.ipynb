# %%
import folium
from folium import plugins
from folium.features import CustomIcon
from folium import IFrame
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/osgeokr/exploreKNP/main/data/{}".format
df = pd.read_csv(url("explore_list.csv"), encoding='utf-8')
df
# Out:
#         CAT_EN CAT_KO NUM        LAT         LON           NAME  \
# 0     Explorer  탐험가코스  S1  36.842245  128.093386  닷돈재\r\n풀옵션야영장
# 1     Explorer  탐험가코스  P1  36.839976  128.094128  닷돈재\r\n풀옵션야영장
# 2     Explorer  탐험가코스  P2  36.838984  128.094206  닷돈재\r\n풀옵션야영장
# 3     Explorer  탐험가코스  P3  36.836047  128.094164  닷돈재\r\n풀옵션야영장
# 4     Explorer  탐험가코스  P4  36.833936  128.097604     무장애\r\n탐방로
# 5     Explorer  탐험가코스  P5  36.833964  128.098845     무장애\r\n탐방로
# 6     Explorer  탐험가코스  P6  36.833858  128.099592     무장애\r\n탐방로
# 7     Explorer  탐험가코스  P7  36.832662  128.102366    만수\r\n자연관찰로
# 8     Explorer  탐험가코스  P8  36.832256  128.104153    만수\r\n자연관찰로
# 9     Explorer  탐험가코스  P9  36.832291  128.101888    만수\r\n자연관찰로
# 10    Explorer  탐험가코스  E0  36.834147  128.096956   만수\r\n탐방지원센터
# 11  Challenger  도전자코스  S1  36.842245  128.093386  닷돈재\r\n풀옵션야영장
# 12  Challenger  도전자코스  P1  36.839976  128.094128  닷돈재\r\n풀옵션야영장
# 13  Challenger  도전자코스  P2  36.838984  128.094206  닷돈재\r\n풀옵션야영장
# 14  Challenger  도전자코스  P3  36.836047  128.094164  닷돈재\r\n풀옵션야영장
# 15  Challenger  도전자코스  P4  36.833936  128.097604     무장애\r\n탐방로
# 16  Challenger  도전자코스  P5  36.833964  128.098845     무장애\r\n탐방로
# 17  Challenger  도전자코스  P6  36.833858  128.099592     무장애\r\n탐방로
# 18  Challenger  도전자코스  E0  36.834147  128.096956   만수\r\n탐방지원센터
# 19    Children  어린이코스  S2  36.834194  128.097047     무장애\r\n탐방로
# 20    Children  어린이코스  P4  36.833936  128.097604     무장애\r\n탐방로
# 21    Children  어린이코스  P5  36.833964  128.098845     무장애\r\n탐방로
# 22    Children  어린이코스  P6  36.833858  128.099592     무장애\r\n탐방로
# 23    Children  어린이코스  E0  36.834147  128.096956   만수\r\n탐방지원센터
#
#                                           DESC  \
# 0   닷돈재 풀옵션야영장 2존 입구\r\n(도전자 코스,탐험가 코스\r\n출발점)
# 1                            만수계곡 주변의\r\n쉼터 의자
# 2                                산나물이 있는 길목의 길
# 3                           미륵리 자연생태학습장\r\n해설판
# 4                               다람쥐와청설모\r\n해설판
# 5                            자연놀이터\r\n통나무 징검다리
# 6                                      송유채취가마터
# 7                              고통받는 소나무\r\n해설판
# 8                               월악산의 지질\r\n해설판
# 9                      데크 다리 위\r\n지의류가 있는 큰 바위
# 10                         도착점\r\n(모든 코스의 도착점)
# 11  닷돈재 풀옵션야영장 2존 입구\r\n(도전자 코스,탐험가 코스\r\n출발점)
# 12                           만수계곡 주변의\r\n쉼터 의자
# 13                               산나물이 있는 길목의 길
# 14                          미륵리 자연생태학습장\r\n해설판
# 15                              다람쥐와청설모\r\n해설판
# 16                           자연놀이터\r\n통나무 징검다리
# 17                                     송유채취가마터
# 18                         도착점\r\n(모든 코스의 도착점)
# 19               무장애탐방 안내판 입구\r\n(어린이 코스의 출발점)
# 20                              다람쥐와청설모\r\n해설판
# 21                           자연놀이터\r\n통나무 징검다리
# 22                                     송유채취가마터
# 23                         도착점\r\n(모든 코스의 도착점)
#
#                                                SLIDE1  SLIDE2  \
# 0   안녕? 나는 월악산 깃대종 산양 '메이'야.\r\n길 잃은 아기산양을 찾으러 와준 ...  S1.jpg
# 1   길을 걷다 쉴 수 있는 의자는 우리 아기산양들이 좋아하는 곳이야.\r\n의자에 앉아...  P1.jpg
# 2   월악산에는 우리 말고도 다양한 친구들이 살고 있어.\r\n야생동물 친구들은 눈에 잘...  P2.jpg
# 3   이곳은 예전에 송어 양식장이었다가 생태복원을 했어. \r\n아기산양이 좋아하는 곳이...  P3.jpg
# 4   숲속 작은 동물친구, 다람쥐와 청설모는 아기산양의 단짝이야. \r\n같은 듯 닮은 ...  P4.jpg
# 5   아기산양은 자연놀이터에서 친구들과 노는걸 좋아해.\r\n통통 징검다리를 타려면 인공...  P5.jpg
# 6   아기산양의 할아버지, 할머니가 옛날이야기를 들려주던 곳이야.\r\n월악산에 사는 옛...  P6.jpg
# 7   눈을 크게 뜨고 주변을 둘러보면 하트를 품은 소나무를 볼 수 있어.\r\n아기산양은...  P7.jpg
# 8   요리봐도 돌, 조리봐도 돌!\r\n월악산의 돌과 절벽은 아기 산양들의 놀이터야.\r...  P8.jpg
# 9   그림 그리기를 좋아하는 아기산양이 회색 바위를 도화지 삼아 상상으로 그림을 그리는 ...  P9.jpg
# 10  아기산양을 모두 구해준 숲속탐사대!\r\n정말 고마워♡\r\n\r\n우리가 보물상자...  E0.jpg
# 11  안녕? 나는 월악산 깃대종 산양 '메이'야.\r\n길 잃은 아기산양을 찾으러 와준 ...  S1.jpg
# 12  길을 걷다 쉴 수 있는 의자는 우리 아기산양들이 좋아하는 곳이야.\r\n의자에 앉아...  P1.jpg
# 13  월악산에는 우리 말고도 다양한 친구들이 살고 있어.\r\n야생동물 친구들은 눈에 잘...  P2.jpg
# 14  이곳은 예전에 송어 양식장이었다가 생태복원을 했어. \r\n아기산양이 좋아하는 곳이...  P3.jpg
# 15  숲속 작은 동물친구, 다람쥐와 청설모는 아기산양의 단짝이야. \r\n같은 듯 닮은 ...  P4.jpg
# 16  아기산양은 자연놀이터에서 친구들과 노는걸 좋아해.\r\n통통 징검다리를 타려면 인공...  P5.jpg
# 17  아기산양의 할아버지, 할머니가 옛날이야기를 들려주던 곳이야.\r\n월악산에 사는 옛...  P6.jpg
# 18  아기산양을 모두 구해준 숲속탐사대!\r\n정말 고마워♡\r\n\r\n우리가 보물상자...  E0.jpg
# 19  안녕? 나는 월악산 깃대종 산양 '메이'야\r\n길 잃은 아기산양을 찾으러 와준 숲...     NaN
# 20  숲속 작은 동물친구, 다람쥐와 청설모는 아기산양의 단짝이야. \r\n같은 듯 닮은 ...  P4.jpg
# 21  아기산양은 자연놀이터에서 친구들과 노는걸 좋아해.\r\n통통 징검다리를 타려면 인공...  P5.jpg
# 22  아기산양의 할아버지, 할머니가 옛날이야기를 들려주던 곳이야.\r\n월악산에 사는 옛...  P6.jpg
# 23  아기산양을 모두 구해준 숲속탐사대!\r\n정말 고마워♡\r\n\r\n우리가 보물상자...  E0.jpg
#
#                                                SLIDE3
# 0                                                 NaN
# 1   자연의 풍경을 눈에 담아요\r\n안녕? 잘 찾아줘서 고마워!\r\n너도 쉼터 의자에...
# 2   발자국 모양을 따라 걸어보자!\r\n야생동물 친구들은 각자 걸음걸이가 다르다는 사실...
# 3   폐달을 밟아라! 스피드레이서!\r\n주변을 둘러봐. 전기를 만드는 자전거가 있어. ...
# 4   다람쥐와 청설모는 닮은꼴 두 동물의 특징을 알아보자.\r\n\r\nQ.다람쥐 등의 ...
# 5   우리 가족 인생샷 찍기\r\n월악산의 멋진 풍경을 담을 수 있는 이 곳!\r\n사진...
# 6   소나무에서 기름이 나온다고요?\r\n송유채취가마터는 소나무에서 기름이 만들어지는 방...
# 7   관찰로 주변에는 하트모양의 소나무들은 사실, 깊게 상처 난 흔적이야. 왜 그런 아픈...
# 8   월악산은 크고 작은 돌이 많아.\r\n모두 다 멋지고 듬직해보이지? 독특한 특징이 ...
# 9   사슴을 찾아라!\r\n\r\n자세히 보면 회색 바위에 붙은 얼룩과 섞인 동물 친구들...
# 10  보물상자를 열어라!\r\n\r\n3자리 숫자를 조합해 보물상자를 열어보렴!\r\n메...
# 11                                                NaN
# 12  자연의 풍경을 눈에 담아요\r\n안녕? 잘 찾아줘서 고마워!\r\n너도 쉼터 의자에...
# 13  발자국 모양을 따라 걸어보자!\r\n야생동물 친구들은 각자 걸음걸이가 다르다는 사실...
# 14  폐달을 밟아라! 스피드레이서!\r\n주변을 둘러봐. 전기를 만드는 자전거가 있어. ...
# 15  다람쥐와 청설모는 닮은꼴 두 동물의 특징을 알아보자.\r\n\r\nQ.다람쥐 등의 ...
# 16  우리 가족 인생샷 찍기\r\n월악산의 멋진 풍경을 담을 수 있는 이 곳!\r\n사진...
# 17  소나무에서 기름이 나온다고요?\r\n송유채취가마터는 소나무에서 기름이 만들어지는 방...
# 18  보물상자를 열어라!\r\n\r\n3자리 숫자를 조합해 보물상자를 열어보렴!\r\n메...
# 19                                                NaN
# 20  다람쥐와 청설모는 닮은꼴 두 동물의 특징을 알아보자.\r\n\r\nQ.다람쥐 등의 ...
# 21  우리 가족 인생샷 찍기\r\n월악산의 멋진 풍경을 담을 수 있는 이 곳!\r\n사진...
# 22  소나무에서 기름이 나온다고요?\r\n송유채취가마터는 소나무에서 기름이 만들어지는 방...
# 23  보물상자를 열어라!\r\n\r\n3자리 숫자를 조합해 보물상자를 열어보렴!\r\n메...

# %%
df_explorer = df[df['CAT_EN']=='Explorer'] # Explorer(탐험가코스)
df_challenger = df[df['CAT_EN']=='Challenger'] # Challenger(도전자코스)
df_children = df[df['CAT_EN']=='Children'] # Children(어린이코스)

# %%
def start_html(url, num):
    return """
    <div class="section">
        <input type="radio" name="slide" id="slide01" checked>
        <input type="radio" name="slide" id="slide02">
        <input type="radio" name="slide" id="slide03">
        <input type="radio" name="slide" id="slide04">
        <input type="radio" name="slide" id="slide05">
        <input type="radio" name="slide" id="slide06">
        <input type="radio" name="slide" id="slide07">
        <input type="radio" name="slide" id="slide08">
        <input type="radio" name="slide" id="slide09">
        <input type="radio" name="slide" id="slide10">
        <input type="radio" name="slide" id="slide11">
        <input type="radio" name="slide" id="slide12">
        <input type="radio" name="slide" id="slide13">
        <input type="radio" name="slide" id="slide14">

        <div class="slidewrap">
            <ul class="slidelist">
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_01.png") + """\" >
                        <label for="slide02" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_02.png") + """\" >
                        <label for="slide03" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide02" class="left"></label>
                            <img src=\"""" + url(num + "_03.png") + """\" >
                        <label for="slide04" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide03" class="left"></label>
                            <img src=\"""" + url(num + "_04.png") + """\" >
                        <label for="slide05" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide04" class="left"></label>
                            <img src=\"""" + url(num + "_05.png") + """\" >
                        <label for="slide06" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide05" class="left"></label>
                            <img src=\"""" + url(num + "_06.png") + """\" >
                        <label for="slide07" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide06" class="left"></label>
                            <img src=\"""" + url(num + "_07.png") + """\" >
                        <label for="slide08" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide07" class="left"></label>
                            <img src=\"""" + url(num + "_08.png") + """\" >
                        <label for="slide09" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide08" class="left"></label>
                            <img src=\"""" + url(num + "_09.png") + """\" >
                        <label for="slide10" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide09" class="left"></label>
                            <img src=\"""" + url(num + "_10.png") + """\" >
                        <label for="slide11" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide10" class="left"></label>
                            <img src=\"""" + url(num + "_11.png") + """\" >
                        <label for="slide12" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide11" class="left"></label>
                            <img src=\"""" + url(num + "_12.png") + """\" >
                        <label for="slide13" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide12" class="left"></label>
                            <img src=\"""" + url(num + "_13.png") + """\" >
                        <label for="slide14" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide13" class="left"></label>
                            <img src=\"""" + url(num + "_14.png") + """\" >
                        <label for="slide14" class="right"></label>
                    </a>
                </li>
            </ul>
        </div>
    </div>
    <style>
        * {margin:0;padding:0;}
        .section input[id*="slide"] {display:none;}

        .section .slidewrap {max-width:240px;margin:0 auto;overflow:hidden;}
        .section .slidelist {white-space:nowrap;font-size:0;}
        .section .slidelist > li {display:inline-block;vertical-align:middle;width:100%;transition:all .5s;}
        .section .slidelist > li > a {display:block;position:relative;}
        .section .slidelist > li > a img {width:100%;}

        .section .slidelist label {position:absolute;z-index:1;top:50%;transform:translateY(-50%);padding:25px;cursor:pointer;}
        .section .slidelist .left {left:10px;background:url(\"""" + url("left.png") + """\") center center / 20% no-repeat;}
        .section .slidelist .right {right:10px;background:url(\"""" + url("right.png") + """\") center center / 20% no-repeat;}

        .section input[id="slide01"]:checked ~ .slidewrap .slidelist > li {transform:translateX(0%);}
        .section input[id="slide02"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-100%);}
        .section input[id="slide03"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-200%);}
        .section input[id="slide04"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-300%);}
        .section input[id="slide05"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-400%);}
        .section input[id="slide06"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-500%);}
        .section input[id="slide07"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-600%);}
        .section input[id="slide08"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-700%);}
        .section input[id="slide09"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-800%);}
        .section input[id="slide10"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-900%);}
        .section input[id="slide11"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-1000%);}
        .section input[id="slide12"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-1100%);}
        .section input[id="slide13"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-1200%);}
        .section input[id="slide14"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-1300%);}
    </style>
    """

# %%
def point_html6(url, num):
    return """
    <div class="section">
        <input type="radio" name="slide" id="slide01" checked>
        <input type="radio" name="slide" id="slide02">
        <input type="radio" name="slide" id="slide03">
        <input type="radio" name="slide" id="slide04">
        <input type="radio" name="slide" id="slide05">
        <input type="radio" name="slide" id="slide06">

        <div class="slidewrap">
            <ul class="slidelist">
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_01.png") + """\" >
                        <label for="slide02" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_02.png") + """\" >
                        <label for="slide03" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide02" class="left"></label>
                            <img src=\"""" + url(num + "_03.png") + """\" >
                        <label for="slide04" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide03" class="left"></label>
                            <img src=\"""" + url(num + "_04.png") + """\" >
                        <label for="slide05" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide04" class="left"></label>
                            <img src=\"""" + url(num + "_05.png") + """\" >
                        <label for="slide06" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide05" class="left"></label>
                            <img src=\"""" + url(num + "_06.png") + """\" >
                        <label for="slide06" class="right"></label>
                    </a>
                </li>
            </ul>
        </div>
    </div>
    <style>
        * {margin:0;padding:0;}
        .section input[id*="slide"] {display:none;}

        .section .slidewrap {max-width:240px;margin:0 auto;overflow:hidden;}
        .section .slidelist {white-space:nowrap;font-size:0;}
        .section .slidelist > li {display:inline-block;vertical-align:middle;width:100%;transition:all .5s;}
        .section .slidelist > li > a {display:block;position:relative;}
        .section .slidelist > li > a img {width:100%;}

        .section .slidelist label {position:absolute;z-index:1;top:50%;transform:translateY(-50%);padding:25px;cursor:pointer;}
        .section .slidelist .left {left:10px;background:url(\"""" + url("left.png") + """\") center center / 20% no-repeat;}
        .section .slidelist .right {right:10px;background:url(\"""" + url("right.png") + """\") center center / 20% no-repeat;}

        .section input[id="slide01"]:checked ~ .slidewrap .slidelist > li {transform:translateX(0%);}
        .section input[id="slide02"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-100%);}
        .section input[id="slide03"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-200%);}
        .section input[id="slide04"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-300%);}
        .section input[id="slide05"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-400%);}
        .section input[id="slide06"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-500%);}
    </style>
    """

# %%
def point_html4(url, num):
    return """
    <div class="section">
        <input type="radio" name="slide" id="slide01" checked>
        <input type="radio" name="slide" id="slide02">
        <input type="radio" name="slide" id="slide03">
        <input type="radio" name="slide" id="slide04">

        <div class="slidewrap">
            <ul class="slidelist">
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_01.png") + """\" >
                        <label for="slide02" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_02.png") + """\" >
                        <label for="slide03" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide02" class="left"></label>
                            <img src=\"""" + url(num + "_03.png") + """\" >
                        <label for="slide04" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide03" class="left"></label>
                            <img src=\"""" + url(num + "_04.png") + """\" >
                        <label for="slide04" class="right"></label>
                    </a>
                </li>
            </ul>
        </div>
    </div>
    <style>
        * {margin:0;padding:0;}
        .section input[id*="slide"] {display:none;}

        .section .slidewrap {max-width:240px;margin:0 auto;overflow:hidden;}
        .section .slidelist {white-space:nowrap;font-size:0;}
        .section .slidelist > li {display:inline-block;vertical-align:middle;width:100%;transition:all .5s;}
        .section .slidelist > li > a {display:block;position:relative;}
        .section .slidelist > li > a img {width:100%;}

        .section .slidelist label {position:absolute;z-index:1;top:50%;transform:translateY(-50%);padding:25px;cursor:pointer;}
        .section .slidelist .left {left:10px;background:url(\"""" + url("left.png") + """\") center center / 20% no-repeat;}
        .section .slidelist .right {right:10px;background:url(\"""" + url("right.png") + """\") center center / 20% no-repeat;}

        .section input[id="slide01"]:checked ~ .slidewrap .slidelist > li {transform:translateX(0%);}
        .section input[id="slide02"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-100%);}
        .section input[id="slide03"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-200%);}
        .section input[id="slide04"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-300%);}
    </style>
    """

# %%
def point_html3(url, num):
    return """
    <div class="section">
        <input type="radio" name="slide" id="slide01" checked>
        <input type="radio" name="slide" id="slide02">
        <input type="radio" name="slide" id="slide03">

        <div class="slidewrap">
            <ul class="slidelist">
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_01.png") + """\" >
                        <label for="slide02" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide01" class="left"></label>
                            <img src=\"""" + url(num + "_02.png") + """\" >
                        <label for="slide03" class="right"></label>
                    </a>
                </li>
                <li>
                    <a>
                        <label for="slide02" class="left"></label>
                            <img src=\"""" + url(num + "_03.png") + """\" >
                        <label for="slide03" class="right"></label>
                    </a>
                </li>
            </ul>
        </div>
    </div>
    <style>
        * {margin:0;padding:0;}
        .section input[id*="slide"] {display:none;}

        .section .slidewrap {max-width:240px;margin:0 auto;overflow:hidden;}
        .section .slidelist {white-space:nowrap;font-size:0;}
        .section .slidelist > li {display:inline-block;vertical-align:middle;width:100%;transition:all .5s;}
        .section .slidelist > li > a {display:block;position:relative;}
        .section .slidelist > li > a img {width:100%;}

        .section .slidelist label {position:absolute;z-index:1;top:50%;transform:translateY(-50%);padding:25px;cursor:pointer;}
        .section .slidelist .left {left:10px;background:url(\"""" + url("left.png") + """\") center center / 20% no-repeat;}
        .section .slidelist .right {right:10px;background:url(\"""" + url("right.png") + """\") center center / 20% no-repeat;}

        .section input[id="slide01"]:checked ~ .slidewrap .slidelist > li {transform:translateX(0%);}
        .section input[id="slide02"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-100%);}
        .section input[id="slide03"]:checked ~ .slidewrap .slidelist > li {transform:translateX(-200%);}
    </style>
    """

# %%
# 타일 유형
m = folium.Map(location=[df.LAT.mean(), df.LON.mean()], zoom_start=16, tiles=None)
folium.raster_layers.TileLayer(tiles='CartoDB positron', name='GPS탐방로').add_to(m)
# Children(어린이코스)
f_children = folium.FeatureGroup(name='어린이코스', overlay=True, show=True)
for index, row in df_children.iterrows():
    # 아이콘
    icon = CustomIcon(url("Children.png"), icon_size=(50, 50))
    # 팝업
    if row['NUM'].startswith('S') == True: # 시점
        html = start_html(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    elif row['NUM'] == 'P2':
        html = point_html6(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    elif row['NUM'] == 'E0':
        html = point_html4(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    else:
        html = point_html3(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    # 마커
    folium.Marker(location=[row['LAT'], row['LON']], icon=icon, popup=popup).add_to(f_children)
    # 폴리라인
    folium.PolyLine(locations=df_children[['LAT', 'LON']].iloc[:-1 , :].values.tolist(),
                    weight=20, color='#1DA462', opacity=0.5).add_to(f_children)
m.add_child(f_children)

# Challenger(도전자코스)
f_challenger = folium.FeatureGroup(name='도전자코스', overlay=True, show=False)
for index, row in df_challenger.iterrows():
    # 아이콘
    icon = CustomIcon(url("Challenger.png"), icon_size=(50, 50))
    # 팝업
    if row['NUM'].startswith('S') == True: # 시점
        html = start_html(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    elif row['NUM'] == 'P2':
        html = point_html6(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    elif row['NUM'] == 'E0':
        html = point_html4(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    else:
        html = point_html3(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    # 마커
    folium.Marker(location=[row['LAT'], row['LON']], icon=icon, popup=popup).add_to(f_challenger)
    # 폴리라인
    folium.PolyLine(locations=df_challenger[['LAT', 'LON']].iloc[:-1 , :].values.tolist(),
                    weight=20, color='#FFCD46', opacity=0.5).add_to(f_challenger)
m.add_child(f_challenger)

# Explorer(탐험가코스)
f_explorer = folium.FeatureGroup(name='탐험가코스', overlay=True, show=False)
for index, row in df_explorer.iterrows():
    # 아이콘
    icon = CustomIcon(url("Explorer.png"), icon_size=(50, 50))
    # 팝업
    if row['NUM'].startswith('S') == True: # 시점
        html = start_html(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    elif row['NUM'] == 'P2':
        html = point_html6(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    elif row['NUM'] == 'E0':
        html = point_html4(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    else:
        html = point_html3(url, row['NUM'])
        popup = folium.Popup(folium.Html(html, script=True), min_width=240, max_width=240)
    # 마커
    folium.Marker(location=[row['LAT'], row['LON']], icon=icon, popup=popup).add_to(f_explorer)
    # 폴리라인
    folium.PolyLine(locations=df_explorer[['LAT', 'LON']].iloc[:-1 , :].values.tolist(),
                    weight=20, color='#DD5144', opacity=0.5).add_to(f_explorer)
m.add_child(f_explorer)

plugins.LocateControl().add_to(m) # 위치 컨트롤 추가
folium.LayerControl(collapsed=False).add_to(m) # 레이어 컨트롤 추가
m.save("index.html") # 파일로 저장
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a65ebc21452a3c4e9fc36b1cba44d41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a65ebc21452a3c4e9fc36b1cba44d41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8a65ebc21452a3c4e9fc36b1cba44d41 = L.map(
#                 &quot;map_8a65ebc21452a3c4e9fc36b1cba44d41&quot;,
#                 {
#                     center: [36.83556755791667, 128.097342255],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cc4b254f4a5e5d772b6d38a590425fd = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a65ebc21452a3c4e9fc36b1cba44d41);
#
#
#             var feature_group_be3b0514b947287ab636b82ec89777ad = L.featureGroup(
#                 {}
#             ).addTo(map_8a65ebc21452a3c4e9fc36b1cba44d41);
#
#
#             var marker_7a5d6c936fb2eac83fbd4d4e3dc94891 = L.marker(
#                 [36.83419444, 128.09704722],
#                 {}
#             ).addTo(feature_group_be3b0514b947287ab636b82ec89777ad);
#
#
#         var custom_icon_1bf9d7aec1f4823eb2440e32698cfc95 = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/osgeokr/exploreKNP/main/data/Children.png&quot;});
#         marker_7a5d6c936fb2eac83fbd4d4e3dc94891.setIcon(custom_icon_1bf9d7aec1f4823eb2440e32698cfc95);
#
#
#         var popup_48c17d2a61581ab67471503fb3da2ce6 = L.popup({&quot;maxWidth&quot;: 240, &quot;minWidth&quot;: 240});
#
#
#             var html_c058d63c42a43158a89d17a9dbd9361e = $(`&lt;div id=&quot;html_c058d63c42a43158a89d17a9dbd9361e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;div class=&quot;section&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide01&quot; checked&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide02&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide03&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide04&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide05&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide06&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide07&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide08&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide09&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide10&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide11&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide12&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide13&quot;&gt;         &lt;input type=&quot;radio&quot; name=&quot;slide&quot; id=&quot;slide14&quot;&gt;          &lt;div class=&quot;slidewrap&quot;&gt;             &lt;ul class=&quot;slidelist&quot;&gt;                 &lt;li&gt;                     &lt;a&gt;                         &lt;label for=&quot;slide01&quot; class=&quot;left&quot;&gt;&lt;/label&gt;                             &lt;img src=&quot;https://raw.githubusercontent.com/osgeokr/exploreKNP/main/data/S2_01.png&quot; &gt;                         &lt;label for=&quot;slide02&quot; class=&quot;right&quot;&gt;&lt;/label&gt;                     &lt;/a&gt;                 &lt;/li&gt;                 &lt;li&gt;                     &lt;a&gt;                         &lt;label for=&quot;slide01&quot; class=&quot;left&quot;&gt;&lt;/label&gt;                             &lt;img src=&quot;https://raw.githubusercontent.com/osgeokr/exploreKNP/main/data/S2_02.png&quot; &gt;                         &lt;label for=&quot;slide03&quot; class=&quot;right&quot;&gt;&lt;/label&gt;                     &lt;/a&gt;                 &lt;/li&gt;                 &lt;li&gt;                     &lt;a&gt;                         &lt;label for=&quot;slide02&quot; class=&quot;left&quot;&gt;&lt;/label&gt;                             &lt;img src=&quot;https://raw.githubusercontent.com/osgeokr/exploreKNP/main/data/S2_03.png&quot; &gt;                         &lt;label for=&quot;slide04&quot; class=&quot;right&quot;&gt;&lt;/label&gt;                     &lt;/a&gt;                 &lt
